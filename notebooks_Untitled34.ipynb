# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample Expense Data
data = {
    "Date": [
        "2026-05-01",
        "2026-05-02",
        "2026-05-03",
        "2026-05-04",
        "2026-05-05",
        "2026-05-06",
        "2026-05-07"
    ],
    
    "Category": [
        "Food",
        "Travel",
        "Shopping",
        "Bills",
        "Food",
        "Entertainment",
        "Travel"
    ],
    
    "Amount": [
        250,
        120,
        1500,
        800,
        300,
        600,
        200
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert Date column to datetime
df["Date"] = pd.to_datetime(df["Date"])

# Save to CSV
df.to_csv("expenses.csv", index=False)

print("Expense Data")
print(df)

# Total Expense
total_expense = df["Amount"].sum()

print("\nTotal Expense:", total_expense)

# Category-wise Expense
category_expense = df.groupby("Category")["Amount"].sum()

print("\nCategory Wise Expense")
print(category_expense)

# Highest Expense Category
highest_category = category_expense.idxmax()
highest_amount = category_expense.max()

print(f"\nHighest Spending Category: {highest_category} = ₹{highest_amount}")

# Plot Bar Chart
plt.figure(figsize=(8,5))
category_expense.plot(kind='bar')

plt.title("Category Wise Expense")
plt.xlabel("Category")
plt.ylabel("Amount")
plt.xticks(rotation=0)

plt.show()

# Plot Pie Chart
plt.figure(figsize=(7,7))

category_expense.plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Expense Distribution")
plt.ylabel("")

plt.show()
# Out:
# Expense Data
#         Date       Category  Amount
# 0 2026-05-01           Food     250
# 1 2026-05-02         Travel     120
# 2 2026-05-03       Shopping    1500
# 3 2026-05-04          Bills     800
# 4 2026-05-05           Food     300
# 5 2026-05-06  Entertainment     600
# 6 2026-05-07         Travel     200
#
# Total Expense: 3770
#
# Category Wise Expense
# Category
# Bills             800
# Entertainment     600
# Food              550
# Shopping         1500
# Travel            320
# Name: Amount, dtype: int64
#
# Highest Spending Category: Shopping = ₹1500

# %%
data = {
    "Category": ["Food", "Travel", "Shopping", "Bills", "Food", "Travel", "Bills", "Shopping"],
    "Amount": [250, 500, 1200, 800, 300, 450, 700, 1500],
    "Month": ["Jan", "Jan", "Jan", "Jan", "Feb", "Feb", "Feb", "Feb"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Category  Amount Month
# 0      Food     250   Jan
# 1    Travel     500   Jan
# 2  Shopping    1200   Jan
# 3     Bills     800   Jan
# 4      Food     300   Feb
# 5    Travel     450   Feb
# 6     Bills     700   Feb
# 7  Shopping    1500   Feb

# %%
print("Shape of Dataset:", df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nDataset Information:")
print(df.info())
# Out:
# Shape of Dataset: (8, 3)
#
# Column Names:
# Index(['Category', 'Amount', 'Month'], dtype='object')
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  8 non-null      object
#  1   Amount    8 non-null      int64
#  2   Month     8 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes
# None

# %%
category_expense.plot(kind='bar')

plt.title("Expense by Category")

plt.xlabel("Category")

plt.ylabel("Amount")

plt.show()

# %%
category_expense.plot(kind='pie', autopct='%1.1f%%')

plt.title("Expense Distribution")

plt.ylabel("")

plt.show()
